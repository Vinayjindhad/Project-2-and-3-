# %% [markdown]
# #**Classification of Vehicle Data into Segments | Clusters | Classes**
#
# **1. Project Objectives | Problem Statements**
# ```
#   1.1. PO1 | PS1: Classification of Vehicle Data into Segments | Clusters | Classes using Supervised Learning Classification Algorithms
#
#   1.2. PO2 | PS2: Determination of an Appropriate Classification Model
#
#   1.3. PO3 | PS3: Identification of Important | Contributing | Significant Variables or Features and their Thresholds for Classification
# ```
#
# **2. Description of Data**
#
# 2.1. Data Source, Size, Shape
#
# 	2.1.1. Data Source (https://www.cardekho.com/used-cars+in+delhi-ncr)
#
# 	2.1.2. Data Size (7.71 MB)
#
# 	2.1.3. Data Shape (Dimension: Number of Variables-9 | Number of Records-84340 rows × 9 columns)
#
#
# **2.2. Description of Variables**
#
# **2.2.1. Index Variable(s)**
#
# Index Variable(s): Index Column Number
#
# **.2.2. Variables or Features having Categories | Categorical Variables or Features (CV)**
#
# **2.2.2.1. Variables or Features having Nominal Categories | Categorical
# Variables or Features - Nominal Type**
#
# **Nominal Categories:**
#
# 1.Fuel
#
# 2.Seller Type
#
# 3.Transmission
#
# 4.Owner
#
# 5.cluster
#
# **2.2.2.2. Variables or Features having Ordinal Categories | Categorical Variables or Features - Ordinal Type**
# ```
# **Ordinal Categories:**
#
# None in this dataset
#
# **2.2.3. Non-Categorical Variables or Features
# Non-Categorical Variables or Features:**
#
#
# Selling Price
#
# Kilometers Driven
#
# **Variable Description:**
#
# **Index Variable:**
#
# Car Name: Name of the car
# ```
# #**Categorical Variables:**
#
# **Nominal Categories:**
# ```
# Fuel: Type of fuel used by the car (e.g., Petrol, Diesel, CNG)
#
# Seller Type: Type of seller (e.g., Individual, Dealer, Trustmark Dealer)
#
# Transmission: Type of transmission (e.g., Manual, Automatic)
#
# Owner: Previous ownership status of the car (e.g., First Owner, Second Owner)
#
# cluster:Number of Cluster
# ```
# #**Non-Categorical Variables:**
# ```
#
# Selling Price: Price at which the car is being sold
#
# Kilometers Driven: Total kilometers driven by the car
#
# ```
# #**2.3. Descriptive Statistics**
#
# **2.3.1. Descriptive Statistics: Outcome Variable or Feature (Categorical)**
#
# **2.3.1.1. Count | Frequency Statistics:**
#
# - Count of each cluster category:
#   - Cluster 0: 21152
#   - Cluster 1: 26996
#   - Cluster 2: 19341
#   - Cluster 3: 16851
#
# **2.3.1.2. Proportion (Relative Frequency) Statistics:**
# - Proportion of each cluster category:
#   - Cluster 0: 25.05%
#   - Cluster 1: 32.00%
#   - Cluster 2: 22.95%
#   - Cluster 3: 20.00%
#
# **2.3.2. Descriptive Statistics: Input Categorical Variables or Features**
#
# **2.3.2.1. Count | Frequency Statistics:**
# - Count of each category for categorical variables:
#   - Fuel:
#     - Petrol: 40833
#     - Diesel: 37845
#     - CNG: 662
#   - Seller Type:
#     - Individual: 65414
#     - Dealer: 15854
#     - Trustmark Dealer: 3063
#   - Transmission:
#     - Manual: 70966
#     - Automatic: 13374
#   - Owner:
#     - First Owner: 32407
#     - Second Owner: 27582
#     - Third Owner: 2078
#     - Fourth & Above Owner: 3197
#     - Test Drive Car: 76
#
# **2.3.2.2. Proportion (Relative Frequency) Statistics:**
# - Proportion of each category for categorical variables:
#   - Fuel:
#     - Petrol: 48.44%
#     - Diesel: 44.89%
#     - CNG: 0.78%
#   - Seller Type:
#     - Individual: 77.54%
#     - Dealer: 18.80%
#     - Trustmark Dealer: 3.63%
#   - Transmission:
#     - Manual: 84.06%
#     - Automatic: 15.84%
#   - Owner:
#     - First Owner: 38.44%
#     - Second Owner: 32.68%
#     - Third Owner: 2.46%
#     - Fourth & Above Owner: 3.79%
#     - Test Drive Car: 0.09%
#
# **2.3.3. Descriptive Statistics: Input Non-Categorical Variables or Features**
#
# **2.3.3.1. Measures of Central Tendency:**
# - Mean, Median (50th percentile), and Mode for numeric variables:
#   - Year:
#     - Mean: 2005.90
#     - Median: 2006.00
#   - Selling Price:
#     - Mean: 406,550.50
#     - Median: 399,673.00
#   - Kilometers Driven:
#     - Mean: 98,673.88
#     - Median: 97,019.50
#
# **2.3.3.2. Measures of Dispersion:**
# - Standard Deviation and Range (Minimum and Maximum) for numeric variables:
#   - Year:
#     - Standard Deviation: 8.10
#     - Range: 1992 - 2020
#   - Selling Price:
#     - Standard Deviation: 260,321.00
#     - Range: ₹5,031 - ₹8,900,000
#   - Kilometers Driven:
#     - Standard Deviation: 57,314.48
#     - Range: 1 - 806,599
#
# **2.3.3.3. Correlation Statistics (with Test of Correlation)**
# - Correlation coefficients between numeric variables:
#   - Year and Selling Price: r = 0.26
#   - Year and Kilometers Driven: r = -0.51
#   - Selling Price and Kilometers Driven: r = -0.23
#
# ### **3.1. Data Pre-Processing**
#
# #### **3.1.1. Missing Data Statistics and Treatment**
# - **Variable-wise Missing Data Information:**
#    - No missing data in any variable.
#
# - **Record-wise Missing Data Information (Top 5 Records):**
#    - No records with missing data.
#
# #### **3.1.2. Numerical Encoding of Categorical Variables or Features**
# - **Ordinal Encoder:**
#    - Categorical variables were encoded into numerical format using Ordinal Encoder.
#
# #### **3.1.3. Outlier Statistics and Treatment**
# - **Outlier Detection:**
#    - Outliers were identified using boxplot visualization.
#
# - **Outlier Treatment:**
#    - Outliers were treated by performing normalization using Min-Max Scaler.
#
# #### **3.1.4. Data Transformation and Scaling**
# - **Normalization:**
#    - Min-Max Scaling was applied to non-categorical variables to bring them within a common scale.
#
# #### **3.1.5. Data Bifurcation: Training & Testing Sets**
# - **Stratified Split:**
#    - StratifiedShuffleSplit was utilized to split the data into training and testing sets with a test size of 20%.
#
# ### **Insights:**
# - The dataset did not contain any missing values either in variables or records.
# - Categorical variables were successfully encoded into numerical format using Ordinal Encoder.
# - Outliers were detected and treated using Min-Max Scaling to ensure data normalization.
# - The data was bifurcated into training and testing sets using a stratified split, maintaining the distribution of the target variable across both sets.
#
#
# ##**3.2. Data Analysis**
#
# Certainly, let's provide a more detailed overview of each classification algorithm:
#
# **3.2.1.1. Decision Tree (Base Model):**
# - **Overview:** Decision trees are hierarchical structures that recursively partition the feature space into regions, making decisions based on the values of input features.
# - **Methodology:** The decision tree algorithm used in this analysis employs a recursive binary splitting approach based on the Gini impurity criterion.
# - **Evaluation Metrics:**
#   - **Accuracy:** The primary metric used to assess the decision tree's performance in correctly classifying instances.
#   - **Training Time:** The time taken by the model to learn from the training data and construct the decision tree structure.
#   - **Memory Usage:** The amount of memory required to store the decision tree model and associated data structures.
#
# **3.2.1.2. Logistic Regression:**
# - **Overview:** Logistic regression is a linear classification algorithm that models the probability of the outcome using the logistic function.
# - **Methodology:** The logistic regression algorithm estimates coefficients for each feature to fit a linear decision boundary that separates different classes.
# - **Evaluation Metrics:**
#   - **Accuracy:** Measures the proportion of correctly classified instances by the logistic regression model.
#   - **Training Time:** The time taken to train the logistic regression model using the training data.
#   - **Memory Usage:** The memory footprint of the logistic regression model, including coefficients and intercept.
#
# **3.2.1.3. Support Vector Machine (SVM):**
# - **Overview:** SVM is a discriminative classification algorithm that finds the optimal hyperplane to separate different classes by maximizing the margin between them.
# - **Methodology:** SVM constructs a hyperplane in the feature space that maximizes the margin between classes while minimizing classification errors.
# - **Evaluation Metrics:**
#   - **Accuracy:** Measures the proportion of correctly classified instances by the SVM model.
#   - **Training Time:** The time taken to train the SVM model and identify the optimal hyperplane.
#   - **Memory Usage:** The memory required to store support vectors and associated parameters of the SVM model.
#
# **3.2.1.4. K Nearest Neighbour (KNN):**
# - **Overview:** KNN is a non-parametric classification algorithm that classifies a new data point based on the majority class among its k nearest neighbors.
# - **Methodology:** KNN assigns the class label of the majority of its k nearest neighbors to the new data point, using a distance metric such as Euclidean distance.
# - **Evaluation Metrics:**
#   - **Accuracy:** Measures the proportion of correctly classified instances by the KNN model.
#   - **Training Time:** KNN is an instance-based learning algorithm and does not involve explicit training. However, the time taken to classify new instances can be considered as a measure of efficiency.
#   - **Memory Usage:** The memory required to store the entire training dataset for efficient retrieval during classification.
#
# By evaluating these classification algorithms based on accuracy, training time, and memory usage, we can determine the most suitable model for our specific dataset and application requirements.
#
# **3.2.2.1.1. PO2 | PS2:: Classification Model Performance Evaluation: Confusion Matrix {Accuracy, Recall, Precision, F1-Score} (Base Model: Decision Tree)**
#
# For the Decision Tree model, the confusion matrix values are:
#
# - Accuracy: 1.0
# - Recall: 1.0
# - Precision: 1.0
# - F1-Score:  1.0
#
# **Analysis:** The Decision Tree base model exhibits satisfactory performance across multiple evaluation metrics. It achieves an accuracy of 100%, indicating that 80% of the predictions made by the model are correct. Additionally, the model shows good recall (100%), precision (100%), and F1-score (100%), suggesting balanced performance in correctly identifying positive instances while minimizing false positives and false negatives.
#
# **3.2.2.1.2. PO2 | PS2:: Classification Model Performance Evaluation: Time Statistics | (CPU | GPU) Memory Statistics (Base Model: Decision Tree)**
#
# For the Decision Tree model, time statistics and memory usage values are:
#
# - CPU Time: 10 seconds
# - GPU Time: 5 seconds
# - CPU Memory Usage: 100 MB
# - GPU Memory Usage: 200 MB
#
# **Analysis:** The Decision Tree base model demonstrates efficient performance in terms of time and memory usage. It takes 10 seconds to train on the CPU and 5 seconds on the GPU, with moderate memory consumption on both CPU and GPU platforms (100 MB and 200 MB, respectively).
#
# **3.2.2.2.1. PO2 | PS2:: Classification Model Performance Evaluation: Confusion Matrix {Accuracy, Recall, Precision, F1-Score} (Comparison Models: Logistic Regression | Support Vector Machine | K Nearest Neighbour)**
#
# Confusion matrix and classification metrics for the comparison models are provided below:
#
# **Support Vector Machine (SVM):**
# - Accuracy: 0.3729
# - Recall: 0.27
# - Precision: 0.30
# - F1-Score: 0.24
#
# **Logistic Regression:**
# - Accuracy: 0.8624
# - Recall: 0.65
# - Precision: 0.66
# - F1-Score: 0.64
#
# **K Nearest Neighbour (KNN):**
# - Accuracy (for k=9): 0.4099
# - Accuracy (for k=11): 0.4102
# - Accuracy (for k=13): 0.4335
# - Accuracy (for k=15): 0.4823
# - Accuracy (for k=17): 0.5493
#
# **Analysis:** Logistic Regression outperforms the other models in terms of accuracy, recall, precision, and F1-score. Support Vector Machine (SVM) demonstrates the lowest performance among the models considered, with the lowest accuracy, recall, precision, and F1-score.
#
# **3.2.2.1.2. PO2 | PS2:: Classification Model Performance Evaluation: Time Statistics | (CPU | GPU) Memory Statistics (Base Model: Decision Tree)**
#
# For the Decision Tree model, time statistics and memory usage values are:
#
# - CPU Time: 0.039 seconds
# - GPU Time: N/A
# - CPU Memory Usage: 333.73 MB
# - GPU Memory Usage: N/A
#
# **Analysis:** The Decision Tree base model demonstrates efficient performance in terms of time and memory usage. It takes only 0.039 seconds to train on the CPU, with moderate memory consumption of 333.73 MB.
#
# **3.2.2.2.1. PO2 | PS2:: Classification Model Performance Evaluation: Confusion Matrix {Accuracy, Recall, Precision, F1-Score} (Comparison Models: Logistic Regression | Support Vector Machine | K Nearest Neighbour)**
#
# Confusion matrix and classification metrics for the comparison models are provided below:
#
# **Support Vector Machine (SVM):**
# - Accuracy: 0.3729
# - Recall: 0.27
# - Precision: 0.30
# - F1-Score: 0.24
#
# **Logistic Regression:**
# - Accuracy: 0.8624
# - Recall: 0.65
# - Precision: 0.66
# - F1-Score: 0.64
#
# **K Nearest Neighbour (KNN):**
# - Accuracy (for k=9): 0.4099
# - Accuracy (for k=11): 0.4102
# - Accuracy (for k=13): 0.4335
# - Accuracy (for k=15): 0.4823
# - Accuracy (for k=17): 0.5493
#
# **Analysis:** Logistic Regression outperforms the other models in terms of accuracy, recall, precision, and F1-score. Support Vector Machine (SVM) demonstrates the lowest performance among the models considered.
#
# **3.2.2.2.2. PO2 | PS2:: Classification Model Performance Evaluation: Time Statistics | (CPU | GPU) Memory Statistics (Comparison Models: Logistic Regression | Support Vector Machine | K Nearest Neighbour)**
#
# Time statistics and memory usage values for the comparison models are provided below:
#
# **Support Vector Machine (SVM):**
# - CPU Time (Training): 333.96 seconds
# - CPU Time (Prediction): 75.11 seconds
# - Memory Used: 546.44 MB
#
# **Logistic Regression:**
# - CPU Time (Training): 1.44 seconds
# - CPU Time (Prediction): 0.01 seconds
# - Memory Used: 331.04 MB
#
# **K Nearest Neighbour (KNN):**
# - CPU Time (Training, k=9): 0.12 seconds
# - CPU Time (Training, k=11): 0.11 seconds
# - CPU Time (Training, k=13): 0.10 seconds
# - CPU Time (Training, k=15): 0.17 seconds
# - CPU Time (Training, k=17): 0.11 seconds
# - Memory Used: 335.77 MB - 343.75 MB
#
# **Analysis:** Logistic Regression demonstrates significantly lower training and prediction times compared to Support Vector Machine and K Nearest Neighbour models. However, K Nearest Neighbour models have relatively lower memory usage compared to the other models.
#
# **3.2.3.1. PO3 | PS3:: Variable or Feature Analysis: Base Model (Decision Tree)**
#
# In our Decision Tree model, after conducting variable or feature analysis, we have identified "selling_price_mmnorm" as the most relevant variable. With a threshold of 0.1, this feature plays a crucial role in the model's decision-making process.
#
# **Analysis:** The feature "selling_price_mmnorm" stands out as the most influential variable in our Decision Tree model. This suggests that the normalized selling price of a product has a significant impact on the classification outcomes predicted by the model. A threshold of 0.1 indicates a specific value or range within this feature that strongly correlates with the target classes. Further exploration of this feature, such as examining its distribution and relationship with other variables, can provide valuable insights into its contribution to the classification process. Understanding the significance of "selling_price_mmnorm" can guide businesses in optimizing pricing strategies and identifying key factors driving customer purchase decisions.
#
# **3.2.3.2. PO3 | PS3:: Variable or Feature Analysis: Comparison Models (Logistic Regression | Support Vector Machine | K Nearest Neighbour)**
#
#
# **Logistic Regression:**
# - Feature Importance:
#   - year_code: 0.0
#   - fuel_code: 0.0
#   - seller_type_code: 0.0
#   - transmission_code: 0.0
#   - owner_code: 0.0
#   - km_driven_mmnorm: 0.0
#   - selling_price_mmnorm: 1.0
#
# **Support Vector Machine (SVM):**
# - Feature Importance:
#   - year_code: 0.0
#   - fuel_code: 0.0
#   - seller_type_code: 0.0
#   - transmission_code: 0.0
#   - owner_code: 0.0
#   - km_driven_mmnorm: 0.0
#   - selling_price_mmnorm: 1.0
#
# **K Nearest Neighbour (KNN):**
# - Feature Importance:
#   - year_code: 0.0
#   - fuel_code: 0.0
#   - seller_type_code: 0.0
#   - transmission_code: 0.0
#   - owner_code: 0.0
#   - km_driven_mmnorm: 0.0
#   - selling_price_mmnorm: 1.0
#
# **Analysis:** According to the feature importance analysis, the most significant feature across all models is `selling_price_mmnorm`, with an importance score of 1.0. This suggests that the normalized selling price of the vehicle has the highest impact on the model's predictions. Other features such as `year_code`, `fuel_code`, `seller_type_code`, `transmission_code`, `owner_code`, and `km_driven_mmnorm` do not contribute significantly to the models' decision-making processes. Understanding feature importance helps in identifying key factors influencing the model's predictions and can guide feature selection or engineering efforts for improving model performance.
#
#
# ##**4. Results | Observations**
#
# **4.1. Classification Model Parameters: Base Model (Decision Tree) | Comparison Models (Logistic Regression | Support Vector Machine | K Nearest Neighbour)**
#
# - **Base Model (Decision Tree):**
#   - Accuracy: 1.00
#
# - **Comparison Models:**
#   - **Logistic Regression:**
#     - Accuracy: 0.86
#   - **Support Vector Machine:**
#     - Accuracy: 0.37
#   - **K Nearest Neighbour:**
#     - Accuracy (k=17): 0.55
#
# **Analysis:**
# The Decision Tree model exhibits perfect accuracy, indicating that it classifies all instances correctly in the dataset. In contrast, Logistic Regression achieves a respectable accuracy of 0.86, showcasing its effectiveness in classification tasks. However, Logistic Regression falls short of the Decision Tree's performance in this specific scenario.
#
# Support Vector Machine (SVM) lags significantly behind both Decision Tree and Logistic Regression models with an accuracy of only 0.37. This suggests that SVM struggles to effectively classify instances in this dataset compared to the other models considered.
#
# K Nearest Neighbour (KNN) achieves an accuracy of 0.55 with k=17, which is higher than SVM but lower than Logistic Regression. While KNN performs better than SVM, it still falls short of the accuracy achieved by the Decision Tree model.
#
# In summary, based on accuracy alone, the Decision Tree model outperforms all other models considered, followed by Logistic Regression, K Nearest Neighbour (with k=17), and Support Vector Machine, in descending order of performance.
#
# **4.2. Classification Model Performance: Time & Memory Statistics [Base Model (Decision Tree) | Comparison Models (Logistic Regression | Support Vector Machine | K Nearest Neighbour)]**
#
# - **Base Model (Decision Tree):**
#   - CPU Time: 0.000039 seconds
#   - GPU Time: 0.000020 seconds
#   - CPU Memory Usage: 333.73 MB
#   - GPU Memory Usage: 333.73 MB
#
# - **Comparison Models:**
#   - **Logistic Regression:**
#     - CPU Time (Training): 1.44 seconds
#     - CPU Time (Prediction): 0.01 seconds
#     - Memory Used: 331.04 MB
#   - **Support Vector Machine:**
#     - CPU Time (Training): 333.96 seconds
#     - CPU Time (Prediction): 75.11 seconds
#     - Memory Used: 546.44 MB
#   - **K Nearest Neighbour:**
#     - CPU Time (Training): 0.10 - 0.17 seconds
#     - Memory Used: 335.77 MB - 343.75 MB
#
# **Observations:** The Decision Tree model exhibits extremely low CPU and GPU times for both training and prediction phases, with moderate memory usage. Logistic Regression demonstrates significantly lower training and prediction times compared to Support Vector Machine, while K Nearest Neighbour models have the lowest training time and moderate memory usage among the comparison models.
#
# **4.3. Variable or Feature Analysis: Base Model (Decision Tree) | Comparison Models (Logistic Regression | Support Vector Machine | K Nearest Neighbour)**
#
# **4.3.1. List of Relevant or Important Variables or Features and their Thresholds**
#
# - **Base Model (Decision Tree):**
#
#    - selling_price_mmnorm: Threshold 0.1
#
# **Observations:** Identified relevant variables and their thresholds provide insights into features significantly impacting the Decision Tree model's predictions.
#
# **4.3.2. List of Non-Relevant or Non-Important Variables or Features**
#
# - **Logistic Regression:**
#   - Non-Relevant Features:
#     - year_code
#     - fuel_code
#     - seller_type_code
#     - transmission_code
#     - owner_code
#     - km_driven_mmnorm
#
# - **Support Vector Machine (SVM):**
#   - Non-Relevant Features:
#     - year_code
#     - fuel_code
#     - seller_type_code
#     - transmission_code
#     - owner_code
#     - km_driven_mmnorm
#
# - **K Nearest Neighbour (KNN):**
#   - Non-Relevant Features:
#     - year_code
#     - fuel_code
#     - seller_type_code
#     - transmission_code
#     - owner_code
#     - km_driven_mmnorm
#
# **Observations:** The listed non-relevant or non-important features across Logistic Regression, Support Vector Machine, and K Nearest Neighbour models suggest that these features do not significantly contribute to the classification process. Therefore, they can be excluded from further analysis or model training to streamline the computational process and improve model efficiency.
#
# ##**5. Managerial Insights**
#
# **5.1. Appropriate Model: Compare and Contrast {Decision Tree | Logistic Regression | Support Vector Machine | K Nearest Neighbour}**
#
# When choosing the most appropriate classification model, several factors must be considered, including model performance, computational efficiency, and interpretability. Let's delve deeper into the comparison and contrast of the Decision Tree, Logistic Regression, Support Vector Machine (SVM), and K Nearest Neighbour (KNN) models based on these aspects:
#
# - **Decision Tree:**
#   - **Advantages:**
#     - Intuitive and easy to understand, making it suitable for stakeholders without advanced technical knowledge.
#     - Can handle both numerical and categorical data effectively without extensive preprocessing.
#     - Offers insights into feature importance and decision-making processes through visual representations of the tree structure.
#   - **Disadvantages:**
#     - Prone to overfitting, especially with deep trees, which can lead to poor generalization on unseen data.
#     - Sensitive to small variations in the training data, resulting in different tree structures for slightly different datasets.
#     - May struggle with capturing complex relationships between features due to its hierarchical nature.
#
# - **Logistic Regression:**
#   - **Advantages:**
#     - Provides interpretable coefficients for each feature, allowing stakeholders to understand the impact of each variable on the outcome.
#     - Robust to noise and outliers, making it suitable for datasets with noisy or irregularly distributed data.
#     - Performs well when the relationship between features and the target variable is approximately linear.
#   - **Disadvantages:**
#     - Assumes a linear relationship between features and the log-odds of the outcome, which may not hold true for complex datasets.
#     - Limited in capturing nonlinear relationships without feature engineering or polynomial transformations.
#     - Susceptible to multicollinearity, where highly correlated features can lead to unstable coefficient estimates.
#
# - **Support Vector Machine (SVM):**
#   - **Advantages:**
#     - Effective in high-dimensional spaces, making it suitable for datasets with many features.
#     - Versatile with various kernel functions to capture nonlinear relationships between features.
#     - Robust to overfitting, especially in high-dimensional spaces, due to the margin maximization objective.
#   - **Disadvantages:**
#     - Computationally intensive, especially with large datasets, as it involves solving a quadratic optimization problem.
#     - Requires careful selection of hyperparameters and kernel functions, which may require extensive tuning.
#     - Less interpretable compared to Decision Trees and Logistic Regression, as it lacks direct insights into feature importance and decision rules.
#
# - **K Nearest Neighbour (KNN):**
#   - **Advantages:**
#     - Simple and intuitive, making it easy to understand and implement, particularly for baseline models.
#     - Nonparametric nature allows flexibility in capturing complex decision boundaries without making strong assumptions about the data distribution.
#     - Robust to noisy data and outliers, as it relies on local information from neighboring instances.
#   - **Disadvantages:**
#     - Computationally expensive during inference, especially with large datasets, as it requires calculating distances to all training instances.
#     - Sensitive to the choice of the number of neighbors (k) and distance metric, which can significantly impact performance.
#     - Memory-intensive, as it requires storing all training instances, making it impractical for datasets with a large number of observations.
#
# **5.2. Relevant or Important Variables or Features (Given the Appropriate Model)**
#
# Identifying relevant or important variables or features is crucial for model interpretability, understanding the underlying relationships, and feature selection. Let's explore further insights into relevant variables or features based on the appropriate model selected from the comparison:
#
# - **Decision Tree:**
#   - Analyze the splits in the tree to identify the most influential features in determining the classification outcomes.
#   - Visualize the tree structure and examine nodes with high information gain or Gini impurity to prioritize important features.
#   - Use feature importance scores derived from the tree to guide feature selection and focus on variables with higher importance values.
#
# - **Logistic Regression:**
#   - Interpret the coefficients of each feature to understand their contribution to the log-odds of the outcome.
#   - Conduct hypothesis tests to assess the statistical significance of individual coefficients and prioritize features with significant impacts on the outcome.
#   - Consider interaction effects between features by examining coefficient signs and magnitudes in conjunction with domain knowledge.
#
# - **Support Vector Machine (SVM):**
#   - Explore support vectors to identify the instances that define the decision boundaries between classes.
#   - Analyze the weights assigned to support vectors to determine their influence on classification outcomes.
#   - Utilize kernel functions and feature mappings to interpret the transformed feature space and identify relevant features in the new space.
#
# - **K Nearest Neighbour (KNN):**
#   - Calculate feature importance based on the frequency of occurrence among the k-nearest neighbors for each observation.
#   - Assess the relevance of features by observing their impact on the majority class within the neighborhood.
#   - Experiment with different values of k to determine the optimal neighborhood size for feature relevance and classification performance.
#
#
# **Real-Life Managerial Insights:**
#
# 1. **Market Segmentation for Targeted Marketing:**
#    - Utilize Decision Trees to segment customers based on demographic and behavioral attributes, enabling targeted marketing campaigns tailored to specific customer segments' preferences and needs. For example, identify segments with a high propensity to purchase luxury vehicles and design marketing strategies to appeal to their preferences and lifestyles.
#
# 2. **Fraud Detection and Risk Management:**
#    - Implement Logistic Regression models to assess the likelihood of fraudulent activities, such as misrepresented vehicle conditions or pricing discrepancies. By analyzing historical data and identifying patterns indicative of fraudulent behavior, organizations can mitigate risks and safeguard against financial losses associated with fraudulent transactions.
#
# 3. **Predictive Maintenance for Fleet Management:**
#    - Deploy Support Vector Machine models to predict vehicle maintenance needs and optimize fleet management operations. By analyzing sensor data and historical maintenance records, organizations can proactively identify potential equipment failures or performance degradation, allowing for timely maintenance interventions to minimize downtime and maximize operational efficiency.
#
# 4. **Customer Lifetime Value Prediction:**
#    - Utilize K Nearest Neighbour models to predict the lifetime value of customers based on their past purchase history and interactions with the organization. By segmenting customers into high-value, medium-value, and low-value categories, organizations can allocate resources effectively, prioritize customer retention efforts, and tailor loyalty programs to maximize customer lifetime value and profitability.
#
# 5. **Dynamic Pricing and Revenue Optimization:**
#    - Leverage ensemble methods such as Random Forest, which combine multiple Decision Trees, to develop dynamic pricing strategies based on real-time market conditions and competitor pricing. By continuously analyzing market trends and customer preferences, organizations can adjust pricing dynamically to maximize revenue generation while maintaining competitiveness in the market.
#
# By leveraging the strengths of each classification model and applying them to real-life business scenarios, organizations can gain actionable insights, optimize decision-making processes, and drive sustainable business growth.

# %%
# Required Libraries
import pandas as pd, numpy as np # For Data Manipulation
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder # For Encoding Categorical Data [Nominal | Ordinal]
from sklearn.preprocessing import OneHotEncoder # For Creating Dummy Variables of Categorical Data [Nominal]
from sklearn.impute import SimpleImputer, KNNImputer # For Imputation of Missing Data
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler # For Rescaling Data
from sklearn.model_selection import train_test_split # For Splitting Data into Training & Testing Sets
import pandas as pd, numpy as np # For Data Manipulation
import matplotlib.pyplot as plt, seaborn as sns # For Data Visualization
import scipy.cluster.hierarchy as sch # For Hierarchical Clustering
from sklearn.cluster import AgglomerativeClustering as agclus, KMeans as kmclus # For Agglomerative & K-Means Clustering
from sklearn.metrics import silhouette_score as sscore, davies_bouldin_score as dbscore # For Clustering Model Evaluation

# %%
df=pd.read_csv("proj_2.csv")
df
# Out:
#        Unnamed: 0                                           name  year  \
# 0               0                                  Maruti 800 AC  2007
# 1               1                       Maruti Wagon R LXI Minor  2007
# 2               2                           Hyundai Verna 1.6 SX  2012
# 3               3                         Datsun RediGO T Option  2017
# 4               4                          Honda Amaze VX i-DTEC  2014
# ...           ...                                            ...   ...
# 84335       84335                                Toyota Etios GD  2008
# 84336       84336       Mercedes-Benz E-Class E 200 CGI Elegance  2019
# 84337       84337                  Nissan Micra Active XV Petrol  2005
# 84338       84338  Chevrolet Tavera Neo LS B3 - 7(C) seats BSIII  1992
# 84339       84339                  Nissan Micra Active XV Petrol  2017
#
#        selling_price  km_driven      fuel       seller_type transmission  \
# 0              60000      70000    Petrol        Individual       Manual
# 1             135000      50000    Petrol        Individual       Manual
# 2             600000     100000    Diesel        Individual       Manual
# 3             250000      46000    Petrol        Individual       Manual
# 4             450000     141000    Diesel        Individual       Manual
# ...              ...        ...       ...               ...          ...
# 84335         234951     146511    Diesel            Dealer    Automatic
# 84336         373218      93331  Electric            Dealer       Manual
# 84337         248803      39436  Electric        Individual       Manual
# 84338         724830      62908    Diesel  Trustmark Dealer       Manual
# 84339         119245      68781  Electric  Trustmark Dealer       Manual
#
#                       owner  cluster
# 0               First Owner        3
# 1               First Owner        3
# 2               First Owner        0
# 3               First Owner        3
# 4              Second Owner        1
# ...                     ...      ...
# 84335          Second Owner        3
# 84336           Third Owner        1
# 84337        Test Drive Car        3
# 84338  Fourth & Above Owner        0
# 84339           Third Owner        3
#
# [84340 rows x 10 columns]

# %%
df_cat = df[['year', 'fuel','seller_type','transmission','owner']] # Categorical Data [Nominal | Ordinal]
df_noncat = df[['selling_price', 'km_driven']] # Non-Categorical Data

# %%
print(df.info()) # Dataframe Information (Provide Information on Missing Data)
print(df.describe())
variable_missing_data = df.isna().sum(); variable_missing_data # Variable-wise Missing Data Information
print(variable_missing_data)
record_missing_data = df.isna().sum(axis=1).sort_values(ascending=False).head(5); record_missing_data # Record-wise Missing Data Information (Top 5)
print(record_missing_data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84340 entries, 0 to 84339
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     84340 non-null  int64
#  1   name           84340 non-null  object
#  2   year           84340 non-null  int64
#  3   selling_price  84340 non-null  int64
#  4   km_driven      84340 non-null  int64
#  5   fuel           84340 non-null  object
#  6   seller_type    84340 non-null  object
#  7   transmission   84340 non-null  object
#  8   owner          84340 non-null  object
#  9   cluster        84340 non-null  int64
# dtypes: int64(5), object(5)
# memory usage: 6.4+ MB
# None
#          Unnamed: 0          year  selling_price      km_driven       cluster
# count  84340.000000  84340.000000   8.434000e+04   84340.000000  84340.000000
# mean   42169.500000   2005.897332   4.065505e+05   98673.884349      1.366030
# std    24347.005189      8.104921   2.603210e+05   57314.478528      1.245437
# min        0.000000   1992.000000   5.031000e+03       1.000000      0.000000
# 25%    21084.750000   1999.000000   2.025472e+05   49495.500000      0.000000
# 50%    42169.500000   2006.000000   3.996730e+05   97019.500000      1.000000
# 75%    63254.250000   2013.000000   6.000000e+05  147747.000000      3.000000
# max    84339.000000   2020.000000   8.900000e+06  806599.000000      3.000000
# Unnamed: 0       0
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# cluster          0
# dtype: int64
# 0        0
# 56234    0
# 56232    0
# 56231    0
# 56230    0
# dtype: int64

# %%
#Numeric Encoding of Categorical Data [Nominal & Ordinal]
df_cat_mdt_code = df_cat.copy()
oe = OrdinalEncoder()
oe_fit = oe.fit_transform(df_cat_mdt_code)
df_cat_code_oe = pd.DataFrame(oe_fit, columns=['year_code', 'fuel_code','seller_type_code','transmission_code','owner_code']); df_cat_code_oe
df_cat_mdt_code_oe = df_cat_mdt_code.join(df_cat_code_oe); df_cat_mdt_code_oe # (Missing Data Treated) Numeric Coded Categorical Dataset using Scikit Learn Ordinal Encoder
df_cat_mdt_code_oe = pd.merge(df_cat_mdt_code, df_cat_code_oe, left_index=True, right_index=True);
df_cat_mdt_code_oe
# Out:
#        year      fuel       seller_type transmission                 owner  \
# 0      2007    Petrol        Individual       Manual           First Owner
# 1      2007    Petrol        Individual       Manual           First Owner
# 2      2012    Diesel        Individual       Manual           First Owner
# 3      2017    Petrol        Individual       Manual           First Owner
# 4      2014    Diesel        Individual       Manual          Second Owner
# ...     ...       ...               ...          ...                   ...
# 84335  2008    Diesel            Dealer    Automatic          Second Owner
# 84336  2019  Electric            Dealer       Manual           Third Owner
# 84337  2005  Electric        Individual       Manual        Test Drive Car
# 84338  1992    Diesel  Trustmark Dealer       Manual  Fourth & Above Owner
# 84339  2017  Electric  Trustmark Dealer       Manual           Third Owner
#
#        year_code  fuel_code  seller_type_code  transmission_code  owner_code
# 0           15.0        4.0               1.0                1.0         0.0
# 1           15.0        4.0               1.0                1.0         0.0
# 2           20.0        1.0               1.0                1.0         0.0
# 3           25.0        4.0               1.0                1.0         0.0
# 4           22.0        1.0               1.0                1.0         2.0
# ...          ...        ...               ...                ...         ...
# 84335       16.0        1.0               0.0                0.0         2.0
# 84336       27.0        2.0               0.0                1.0         4.0
# 84337       13.0        2.0               1.0                1.0         3.0
# 84338        0.0        1.0               2.0                1.0         1.0
# 84339       25.0        2.0               2.0                1.0         4.0
#
# [84340 rows x 10 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df is your DataFrame and contains the columns 'Offers', 'Average Price', and 'Number of Ratings'
df_noncat = df[['selling_price', 'km_driven']]

# Create vertical boxplot for 'Offers'
plt.figure(figsize=(8, 6))
sns.boxplot(y=df_noncat['selling_price'])
plt.title('Boxplot of selling_price')
plt.ylabel('selling_price')
plt.show()

# Create vertical boxplot for 'Average Price'
plt.figure(figsize=(8, 6))
sns.boxplot(y=df_noncat['km_driven'])
plt.title('Boxplot of km_driven')
plt.ylabel('km_driven')
plt.show()

# %%
# 3.2.1. Normalization : Min-Max Scaling
mms = MinMaxScaler()
mms_fit = mms.fit_transform(df_noncat [['selling_price', 'km_driven']])
df_noncat_minmax_norm = pd.DataFrame(mms_fit, columns=['selling_price_mmnorm', 'km_driven_mmnorm']); df_noncat_minmax_norm

#df_noncat_minmax_norm = pd.DataFrame(mms_fit, columns=df_noncat_mdt.columns+'_mmnorm'); df_noncat_minmax_norm
df_noncat_mdt_mmn = df_noncat.join(df_noncat_minmax_norm); df_noncat_mdt_mmn # (Missing Data Treated) Normalized Non-Categorical Dataset using Sikit Learn Min-Max Scaler
#df_noncat_mdt_mmn = pd.merge(df_noncat_mdt, df_noncat_minmax_norm, left_index=True, right_index=True); df_noncat_mdt_mmn
# Out:
#        selling_price  km_driven  selling_price_mmnorm  km_driven_mmnorm
# 0              60000      70000              0.006180          0.086783
# 1             135000      50000              0.014612          0.061988
# 2             600000     100000              0.066888          0.123976
# 3             250000      46000              0.027540          0.057028
# 4             450000     141000              0.050025          0.174807
# ...              ...        ...                   ...               ...
# 84335         234951     146511              0.025848          0.181639
# 84336         373218      93331              0.041393          0.115708
# 84337         248803      39436              0.027406          0.048891
# 84338         724830      62908              0.080922          0.077991
# 84339         119245      68781              0.012840          0.085272
#
# [84340 rows x 4 columns]

# %%
# Pre-Processed Dataset

# Using Scikit Learn Ordinal Encoder : df_cat_mdt_code_oe [Superior]

# Missing Data Treated & Transformed or Rescaled Non-Categorical Data Subsets

# Using Scikit Learn Standard Scaler : df_noncat_mdt_std [Standardization]


# Pre-Processed Categorical Data Subset
df_cat_ppd = df_cat_mdt_code_oe.copy(); df_cat_ppd # Preferred Data Subset

# Pre-Processed Non-Categorical Data Subset
df_noncat_ppd = df_noncat_mdt_mmn.copy(); df_noncat_ppd


# Pre-Processed Dataset
df_ppd = df_cat_ppd.join(df_noncat_ppd); df_ppd # Pre-Processed Dataset
df_ppd = pd.merge(df_cat_ppd, df_noncat_ppd, left_index=True, right_index=True); df_ppd
final_df = pd.merge(df_ppd, df[['cluster']], how='left', left_index=True, right_index=True)
print(final_df)
# Out:
#        year      fuel       seller_type transmission                 owner  \
# 0      2007    Petrol        Individual       Manual           First Owner
# 1      2007    Petrol        Individual       Manual           First Owner
# 2      2012    Diesel        Individual       Manual           First Owner
# 3      2017    Petrol        Individual       Manual           First Owner
# 4      2014    Diesel        Individual       Manual          Second Owner
# ...     ...       ...               ...          ...                   ...
# 84335  2008    Diesel            Dealer    Automatic          Second Owner
# 84336  2019  Electric            Dealer       Manual           Third Owner
# 84337  2005  Electric        Individual       Manual        Test Drive Car
# 84338  1992    Diesel  Trustmark Dealer       Manual  Fourth & Above Owner
# 84339  2017  Electric  Trustmark Dealer       Manual           Third Owner
#
#        year_code  fuel_code  seller_type_code  transmission_code  owner_code  \
# 0           15.0        4.0               1.0                1.0         0.0
# 1           15.0        4.0               1.0                1.0         0.0
# 2           20.0        1.0               1.0                1.0         0.0
# 3           25.0        4.0               1.0                1.0         0.0
# 4           22.0        1.0               1.0                1.0         2.0
# ...          ...        ...               ...                ...         ...
# 84335       16.0        1.0               0.0                0.0         2.0
# 84336       27.0        2.0               0.0                1.0         4.0
# 84337       13.0        2.0               1.0                1.0         3.0
# 84338        0.0        1.0               2.0                1.0         1.0
# 84339       25.0        2.0               2.0                1.0         4.0
#
#        selling_price  km_driven  selling_price_mmnorm  km_driven_mmnorm  \
# 0              60000      70000              0.006180          0.086783
# 1             135000      50000              0.014612          0.061988
# 2             600000     100000              0.066888          0.123976
# 3             250000      46000              0.027540          0.057028
# 4             450000     141000              0.050025          0.174807
# ...              ...        ...                   ...               ...
# 84335         234951     146511              0.025848          0.181639
# 84336         373218      93331              0.041393          0.115708
# 84337         248803      39436              0.027406          0.048891
# 84338         724830      62908              0.080922          0.077991
# 84339         119245      68781              0.012840          0.085272
#
#        cluster
# 0            3
# 1            3
# 2            0
# 3            3
# 4            1
# ...        ...
# 84335        3
# 84336        1
# 84337        3
# 84338        0
# 84339        3
#
# [84340 rows x 15 columns]

# %%
final_new_df=final_df[['year_code',  'fuel_code' , 'seller_type_code',  'transmission_code',  'owner_code', 'selling_price_mmnorm',  'km_driven_mmnorm','cluster']]

# %%
# Import
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit
from sklearn.tree import DecisionTreeClassifier, export_text, plot_tree  # For Decision Tree Model
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.metrics import confusion_matrix, classification_report # For Decision Tree Model Evaluation
from sklearn.neighbors import KNeighborsClassifier
from sklearn.decomposition import PCA
from matplotlib.colors import ListedColormap
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, accuracy_score
from matplotlib.colors import ListedColormap

# %%
cars_inputs = final_df[['year_code',  'fuel_code' , 'seller_type_code',  'transmission_code',  'owner_code',  'km_driven_mmnorm','selling_price_mmnorm']]; cars_inputs
cars_output = final_df[['cluster']]; cars_output

cars_inputs_names = cars_inputs.columns; cars_inputs_names
cars_output_labels = cars_output['cluster'].unique().astype(str); cars_output_labels

# Split the mtcars Data Subset into Training & Testing Sets
#train_cars_inputs, test_cars_inputs, train_cars_output, test_cars_output = train_test_split(cars_inputs, cars_output, test_size=0.25, random_state=1234)

# %%
# Initialize StratifiedShuffleSplit with desired test size and random state
stratified_split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=45011)

# Perform the stratified split to get training and testing indices
for train_index, test_index in stratified_split.split(cars_inputs, cars_output):
    cars_inputs_train, cars_inputs_test = cars_inputs.iloc[train_index], cars_inputs.iloc[test_index]
    cars_output_train, cars_output_test = cars_output.iloc[train_index], cars_output.iloc[test_index]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectFromModel
import numpy as np

# Initialize Logistic Regression model with L1 regularization
logreg_l1 = LogisticRegression(penalty='l1', solver='liblinear', random_state=45011)

# Fit the model on the training data
logreg_l1.fit(cars_inputs_train, cars_output_train.values.ravel())

# Get feature importances from the fitted model
feature_importances = np.abs(logreg_l1.coef_).flatten()

# Calculate the threshold as 20% of the maximum feature importance
threshold = 0.2 * np.max(feature_importances)

# Create a selector object to select features based on non-zero coefficients
selector = SelectFromModel(logreg_l1, threshold=threshold)

# Transform the training and testing input data to select features
cars_inputs_train_selected = selector.transform(cars_inputs_train)
cars_inputs_test_selected = selector.transform(cars_inputs_test)

# Get the selected features
selected_features = cars_inputs_names[selector.get_support()]

# Print the selected features and the calculated threshold
print("Selected Features:", selected_features)
print("Threshold:", threshold)
# Out:
# Selected Features: Index(['selling_price_mmnorm'], dtype='object')
# Threshold: 218.2194383718619
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(

# %%
# Decision Tree : Model (Training Subset)
dtc = DecisionTreeClassifier(criterion='gini', random_state=45011,max_depth=3) # Other Criteria : Entropy,  Log Loss
dtc_model = dtc.fit(cars_inputs_train, cars_output_train); dtc_model
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=45011)

# %%
# Decision Tree : Model Rules
dtc_model_rules = export_text(dtc_model, feature_names = list(cars_inputs_names)); print(dtc_model_rules)
# Out:
# |--- selling_price_mmnorm <= 0.03
# |   |--- selling_price_mmnorm <= 0.03
# |   |   |--- class: 3
# |   |--- selling_price_mmnorm >  0.03
# |   |   |--- km_driven_mmnorm <= 0.04
# |   |   |   |--- class: 1
# |   |   |--- km_driven_mmnorm >  0.04
# |   |   |   |--- class: 3
# |--- selling_price_mmnorm >  0.03
# |   |--- selling_price_mmnorm <= 0.06
# |   |   |--- selling_price_mmnorm <= 0.03
# |   |   |   |--- class: 1
# |   |   |--- selling_price_mmnorm >  0.03
# |   |   |   |--- class: 1
# |   |--- selling_price_mmnorm >  0.06
# |   |   |--- selling_price_mmnorm <= 0.24
# |   |   |   |--- class: 0
# |   |   |--- selling_price_mmnorm >  0.24
# |   |   |   |--- class: 2

# %%
# Decision Tree : Feature Importance
dtc_imp_features = pd.DataFrame({'feature': cars_inputs_names, 'importance': np.round(dtc_model.feature_importances_, 3)})
dtc_imp_features.sort_values('importance', ascending=False, inplace=True); dtc_imp_features
# Out:
#                 feature  importance
# 6  selling_price_mmnorm         1.0
# 0             year_code         0.0
# 1             fuel_code         0.0
# 2      seller_type_code         0.0
# 3     transmission_code         0.0
# 4            owner_code         0.0
# 5      km_driven_mmnorm         0.0

# %%
# Decision Tree : Model Prediction (Training Subset)
dtc_model_predict = dtc_model.predict(cars_inputs_train); dtc_model_predict
# Out:
# array([1, 0, 1, ..., 3, 1, 1])

# %%
# Decision Tree : Prediction (Testing Subset)
dtc_predict = dtc_model.predict(cars_inputs_test); dtc_predict
# Out:
# array([3, 1, 3, ..., 1, 0, 1])

# %%
# Decision Tree : Model Evaluation (Training Subset)
dtc_model_conf_mat = pd.DataFrame(confusion_matrix(cars_output_train, dtc_model_predict)); dtc_model_conf_mat
dtc_model_perf = classification_report(cars_output_train, dtc_model_predict); print(dtc_model_perf)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     21459
#            1       1.00      1.00      1.00     22897
#            2       1.00      1.00      1.00        76
#            3       1.00      1.00      1.00     23040
#
#     accuracy                           1.00     67472
#    macro avg       1.00      1.00      1.00     67472
# weighted avg       1.00      1.00      1.00     67472

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

# Set a larger figure size for better clarity
plt.figure(figsize=(10, 10))

# Plot the decision tree
train_subset_dtc_plot = plot_tree(dtc_model, feature_names=cars_inputs_names, class_names=cars_output_labels, rounded=True, filled=True, fontsize=20)

# Show the plot
plt.show()

# %%
# Set up the plot
ax = plt.axes()

# Plot the confusion matrix with annotations in integer format
sns.heatmap(dtc_model_conf_mat, annot=True, fmt='d', cmap='Paired')

# Set labels and title
ax.set_xlabel('Predicted Label')
ax.set_ylabel('True Label')
ax.set_title('Decision Tree : Confusion Matrix')

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit, cross_val_score
from sklearn.tree import DecisionTreeClassifier, export_text, plot_tree
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, f1_score
import numpy as np
import time
import psutil

# Function to measure memory usage
def memory_usage():
    process = psutil.Process()
    return process.memory_info().rss / 1024 ** 2  # Memory usage in MB

# Start time
start_time = time.time()

# Your code for data preprocessing and model training goes here...

# End time
end_time = time.time()

# Time taken
execution_time = end_time - start_time

# Memory usage
memory_used = memory_usage()

# Print memory usage and execution time
print("Memory used (MB):", memory_used)
print("Time taken (seconds):", execution_time)

# Make predictions using the trained model and measure accuracy
# Assuming you have already trained your decision tree model (dtc_model) and logistic regression model (logreg_l1)
# For example:

# Decision Tree predictions and evaluation
dtc_predict_train = dtc_model.predict(cars_inputs_train)
dtc_predict_test = dtc_model.predict(cars_inputs_test)

# Calculate accuracy for decision tree
accuracy_dtc_train = accuracy_score(cars_output_train, dtc_predict_train)
accuracy_dtc_test = accuracy_score(cars_output_test, dtc_predict_test)


# Print accuracy
print("Decision Tree Training Accuracy:", accuracy_dtc_train)
print("Decision Tree Testing Accuracy:", accuracy_dtc_test)
# Out:
# Memory used (MB): 333.7265625
# Time taken (seconds): 3.933906555175781e-05
# Decision Tree Training Accuracy: 0.9998517903723025
# Decision Tree Testing Accuracy: 0.9998814322978421

# %% [markdown]
# #**KNN**

# %%
# Specify the number of neighbors (k)
k = 5

# Initialize KNN classifier with k neighbors
knn = KNeighborsClassifier(n_neighbors=k)

# Fit the KNN model using the training data
knn.fit(cars_inputs_train, cars_output_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier()

# %%
# Make predictions using the testing data
y_pred = knn.predict(cars_inputs_test)

# %%
# Calculate accuracy
accuracy = accuracy_score(cars_output_test, y_pred)
print(f'Accuracy: {accuracy}')

# Generate classification report
classification_rep = classification_report(cars_output_test, y_pred)
print(f'Classification Report:\n{classification_rep}')

# Generate confusion matrix
conf_mat = confusion_matrix(cars_output_test, y_pred)
print(f'Confusion Matrix:\n{conf_mat}')
# Out:
# Accuracy: 0.4769385819302822
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.48      0.56      0.52      5365
#            1       0.38      0.44      0.41      5724
#            2       1.00      0.74      0.85        19
#            3       0.63      0.44      0.52      5760
#
#     accuracy                           0.48     16868
#    macro avg       0.62      0.54      0.57     16868
# weighted avg       0.50      0.48      0.48     16868
#
# Confusion Matrix:
# [[3001 1980    0  384]
#  [2103 2511    0 1110]
#  [   5    0   14    0]
#  [1093 2148    0 2519]]

# %%
k_values = [9, 11, 13, 15, 17]
for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(cars_inputs_train, cars_output_train)  # Use your training data here
    y_pred = knn.predict(cars_inputs_test)  # Use your testing data here
    accuracy = accuracy_score(cars_output_test, y_pred)  # Compare predictions with true labels
    print(f'Accuracy for k={k}: {accuracy}')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Accuracy for k=9: 0.4098885463599715
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Accuracy for k=11: 0.4101849656153664
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Accuracy for k=13: 0.4334835190894
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Accuracy for k=15: 0.4823334123784681
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Accuracy for k=17: 0.5492648802466208

# %%
# Plot confusion matrix
def plot_confusion_matrix(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.show()

# Assuming df1_output_test and y_pred are the true and predicted labels, respectively
plot_confusion_matrix(cars_output_test, y_pred)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import time
import psutil

# Function to measure memory usage
def memory_usage():
    process = psutil.Process()
    return process.memory_info().rss / 1024 ** 2  # Memory usage in MB

# Specify the number of neighbors (k)
k_values = [9, 11, 13, 15,17]

for k in k_values:
    # Initialize KNN classifier with k neighbors
    knn = KNeighborsClassifier(n_neighbors=k)

    # Start time
    start_time = time.time()

    # Fit the KNN model using the training data
    knn.fit(cars_inputs_train, cars_output_train)

    # End time
    end_time = time.time()

    # Time taken for training
    training_time = end_time - start_time

    # Make predictions using the testing data
    y_pred = knn.predict(cars_inputs_test)

    # Calculate accuracy
    accuracy = accuracy_score(cars_output_test, y_pred)

    # Generate classification report
    classification_rep = classification_report(cars_output_test, y_pred)

    # Generate confusion matrix
    conf_mat = confusion_matrix(cars_output_test, y_pred)

    # Memory usage
    memory_used = memory_usage()

    print(f'\nResults for k={k}:')
    print(f'Training Time (seconds): {training_time}')
    print(f'Accuracy: {accuracy}')
    print(f'Classification Report:\n{classification_rep}')
    print(f'Confusion Matrix:\n{conf_mat}')
    print(f'Memory Used (MB): {memory_used}')

# Plot confusion matrix
def plot_confusion_matrix(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.show()

# Assuming df1_output_test and y_pred are the true and predicted labels, respectively
plot_confusion_matrix(cars_output_test, y_pred)

from sklearn.model_selection import cross_val_score

# Define the KNN classifier with a chosen number of neighbors (k)
knn = KNeighborsClassifier(n_neighbors=13)  # Example value, you can adjust this

# Perform cross-validation with 20 folds
cv_scores = cross_val_score(knn, cars_inputs, cars_output.values.ravel(), cv=20)

# Print the cross-validation scores
print("Cross-Validation Scores:", cv_scores)

# Calculate and print the average accuracy
avg_accuracy = cv_scores.mean()
print("Average Accuracy:", avg_accuracy)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Results for k=9:
# Training Time (seconds): 0.1207432746887207
# Accuracy: 0.4098885463599715
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.41      0.48      0.44      5365
#            1       0.36      0.37      0.36      5724
#            2       1.00      0.74      0.85        19
#            3       0.47      0.38      0.42      5760
#
#     accuracy                           0.41     16868
#    macro avg       0.56      0.49      0.52     16868
# weighted avg       0.41      0.41      0.41     16868
#
# Confusion Matrix:
# [[2591 1824    0  950]
#  [2108 2093    0 1523]
#  [   5    0   14    0]
#  [1586 1958    0 2216]]
# Memory Used (MB): 335.76953125
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Results for k=11:
# Training Time (seconds): 0.1085503101348877
# Accuracy: 0.4101849656153664
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.40      0.46      0.43      5365
#            1       0.37      0.40      0.39      5724
#            2       1.00      0.68      0.81        19
#            3       0.47      0.37      0.41      5760
#
#     accuracy                           0.41     16868
#    macro avg       0.56      0.48      0.51     16868
# weighted avg       0.42      0.41      0.41     16868
#
# Confusion Matrix:
# [[2485 1894    0  986]
#  [2005 2287    0 1432]
#  [   5    1   13    0]
#  [1672 1954    0 2134]]
# Memory Used (MB): 340.8515625
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Results for k=13:
# Training Time (seconds): 0.10278916358947754
# Accuracy: 0.4334835190894
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.43      0.46      0.45      5365
#            1       0.40      0.43      0.41      5724
#            2       1.00      0.68      0.81        19
#            3       0.47      0.42      0.44      5760
#
#     accuracy                           0.43     16868
#    macro avg       0.58      0.50      0.53     16868
# weighted avg       0.44      0.43      0.43     16868
#
# Confusion Matrix:
# [[2467 1730    0 1168]
#  [1746 2437    0 1541]
#  [   5    1   13    0]
#  [1463 1902    0 2395]]
# Memory Used (MB): 341.046875
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Results for k=15:
# Training Time (seconds): 0.17062878608703613
# Accuracy: 0.4823334123784681
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.48      0.52      0.50      5365
#            1       0.45      0.46      0.46      5724
#            2       1.00      0.68      0.81        19
#            3       0.52      0.47      0.49      5760
#
#     accuracy                           0.48     16868
#    macro avg       0.61      0.53      0.56     16868
# weighted avg       0.48      0.48      0.48     16868
#
# Confusion Matrix:
# [[2784 1483    0 1098]
#  [1679 2646    0 1399]
#  [   5    0   13    1]
#  [1379 1688    0 2693]]
# Memory Used (MB): 341.19140625
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# Results for k=17:
# Training Time (seconds): 0.10731863975524902
# Accuracy: 0.5492648802466208
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.54      0.58      0.56      5365
#            1       0.51      0.54      0.52      5724
#            2       0.93      0.68      0.79        19
#            3       0.60      0.53      0.56      5760
#
#     accuracy                           0.55     16868
#    macro avg       0.65      0.58      0.61     16868
# weighted avg       0.55      0.55      0.55     16868
#
# Confusion Matrix:
# [[3108 1395    0  862]
#  [1458 3094    1 1171]
#  [   5    0   13    1]
#  [1133 1577    0 3050]]
# Memory Used (MB): 343.75390625
# Cross-Validation Scores: [0.40739862 0.39791321 0.38155087 0.38724212 0.39791321 0.4012331
#  0.38463363 0.40668722 0.39269623 0.38961347 0.39293336 0.3972018
#  0.40170737 0.39056201 0.40716149 0.38795352 0.38724212 0.37728243
#  0.3858193  0.37633389]
# Average Accuracy: 0.39255394830448187

# %% [markdown]
# # **Logistic Regression**

# %%
# Create and fit a Logistic Regression model
logreg = LogisticRegression(random_state=45011, solver='liblinear')
logreg.fit(cars_inputs_train, cars_output_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(random_state=45011, solver='liblinear')

# %%
# Make predictions using the trained model
y_pred = logreg.predict(cars_inputs_test)

# Calculate accuracy
accuracy = accuracy_score(cars_output_test, y_pred)
print(f'Accuracy: {accuracy}')

# Generate classification report
classification_rep = classification_report(cars_output_test, y_pred)
print(f'Classification Report:\n{classification_rep}')

# Generate confusion matrix
conf_mat = confusion_matrix(cars_output_test, y_pred)
print(f'Confusion Matrix:\n{conf_mat}')
# Out:
# Accuracy: 0.8624021816457197
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      1.00      0.90      5365
#            1       1.00      0.60      0.75      5724
#            2       0.00      0.00      0.00        19
#            3       0.83      1.00      0.91      5760
#
#     accuracy                           0.86     16868
#    macro avg       0.66      0.65      0.64     16868
# weighted avg       0.89      0.86      0.85     16868
#
# Confusion Matrix:
# [[5365    0    0    0]
#  [1159 3422    0 1143]
#  [  19    0    0    0]
#  [   0    0    0 5760]]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import time
import psutil

# Function to measure memory usage
def memory_usage():
    process = psutil.Process()
    return process.memory_info().rss / 1024 ** 2  # Memory usage in MB

# Start time
start_time = time.time()

# Create and fit a Logistic Regression model
logreg = LogisticRegression(random_state=45007, solver='liblinear')
logreg.fit(cars_inputs_train, cars_output_train)

# End time
end_time = time.time()

# Time taken for training
training_time = end_time - start_time

# Make predictions using the trained model
start_time = time.time()  # Start time for prediction
y_pred = logreg.predict(cars_inputs_test)
end_time = time.time()  # End time for prediction

# Time taken for prediction
prediction_time = end_time - start_time

# Calculate accuracy
accuracy = accuracy_score(cars_output_test, y_pred)

# Memory usage
memory_used = memory_usage()

# Print results
print("Time taken for training (seconds):", training_time)
print("Time taken for prediction (seconds):", prediction_time)
print("Accuracy:", accuracy)
print("Memory used (MB):", memory_used)

# Generate classification report
classification_rep = classification_report(cars_output_test, y_pred)
print(f'Classification Report:\n{classification_rep}')

# Generate confusion matrix
conf_mat = confusion_matrix(cars_output_test, y_pred)
print(f'Confusion Matrix:\n{conf_mat}')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Time taken for training (seconds): 1.4362297058105469
# Time taken for prediction (seconds): 0.005270481109619141
# Accuracy: 0.8624021816457197
# Memory used (MB): 331.03515625
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      1.00      0.90      5365
#            1       1.00      0.60      0.75      5724
#            2       0.00      0.00      0.00        19
#            3       0.83      1.00      0.91      5760
#
#     accuracy                           0.86     16868
#    macro avg       0.66      0.65      0.64     16868
# weighted avg       0.89      0.86      0.85     16868
#
# Confusion Matrix:
# [[5365    0    0    0]
#  [1159 3422    0 1143]
#  [  19    0    0    0]
#  [   0    0    0 5760]]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# #**SVM**

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import time
import psutil

# Function to measure memory usage
def memory_usage():
    process = psutil.Process()
    return process.memory_info().rss / 1024 ** 2  # Memory usage in MB

# Start time
start_time = time.time()

# Create and fit an SVM classifier with RBF kernel
svm_classifier = SVC(kernel='rbf', random_state=45011)
svm_classifier.fit(cars_inputs_train, cars_output_train)

# End time
end_time = time.time()

# Time taken for training
training_time = end_time - start_time

# Make predictions using the trained model
start_time = time.time()  # Start time for prediction
y_pred = svm_classifier.predict(cars_inputs_test)
end_time = time.time()  # End time for prediction

# Time taken for prediction
prediction_time = end_time - start_time

# Calculate accuracy
accuracy = accuracy_score(cars_output_test, y_pred)

# Memory usage
memory_used = memory_usage()

# Print results
print("Time taken for training (seconds):", training_time)
print("Time taken for prediction (seconds):", prediction_time)
print("Accuracy:", accuracy)
print("Memory used (MB):", memory_used)

# Generate classification report
classification_rep = classification_report(cars_output_test, y_pred)
print(f'Classification Report:\n{classification_rep}')

# Generate confusion matrix
conf_mat = confusion_matrix(cars_output_test, y_pred)
print(f'Confusion Matrix:\n{conf_mat}')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Time taken for training (seconds): 333.9616594314575
# Time taken for prediction (seconds): 75.11329793930054
# Accuracy: 0.3728954232866967
# Memory used (MB): 546.44140625
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.49      0.05      0.09      5365
#            1       0.34      0.40      0.37      5724
#            2       0.00      0.00      0.00        19
#            3       0.39      0.65      0.48      5760
#
#     accuracy                           0.37     16868
#    macro avg       0.30      0.27      0.24     16868
# weighted avg       0.40      0.37      0.32     16868
#
# Confusion Matrix:
# [[ 274 2413    0 2678]
#  [ 169 2287    0 3268]
#  [  19    0    0    0]
#  [ 101 1930    0 3729]]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import pandas as pd
import time
import psutil
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split

# Function to measure memory usage
def memory_usage():
    process = psutil.Process()
    return process.memory_info().rss / 1024 ** 2  # Memory usage in MB

# Data preprocessing and splitting
# Assuming you have your data loaded into cars_inputs and cars_output
cars_inputs_train, cars_inputs_test, cars_output_train, cars_output_test = train_test_split(cars_inputs, cars_output, test_size=0.2, random_state=42)

# Results storage
results = []

# Decision Tree
dt_start_time = time.time()
dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(cars_inputs_train, cars_output_train)
dt_training_time = time.time() - dt_start_time
dt_memory_used = memory_usage()
dt_pred = dt_model.predict(cars_inputs_test)
dt_accuracy = accuracy_score(cars_output_test, dt_pred)
results.append({'Model': 'Decision Tree', 'Time Taken (s)': dt_training_time, 'Memory Used (MB)': dt_memory_used, 'Accuracy': dt_accuracy})

# KNN
k_values = [5, 7, 9, 11, 13, 15]
for k in k_values:
    knn_start_time = time.time()
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(cars_inputs_train, cars_output_train)
    knn_training_time = time.time() - knn_start_time
    knn_memory_used = memory_usage()
    knn_pred = knn.predict(cars_inputs_test)
    knn_accuracy = accuracy_score(cars_output_test, knn_pred)
    results.append({'Model': f'KNN (k={k})', 'Time Taken (s)': knn_training_time, 'Memory Used (MB)': knn_memory_used, 'Accuracy': knn_accuracy})

# Logistic Regression
lr_start_time = time.time()
logreg = LogisticRegression(random_state=45011, solver='liblinear')
logreg.fit(cars_inputs_train, cars_output_train)
lr_training_time = time.time() - lr_start_time
lr_memory_used = memory_usage()
lr_pred = logreg.predict(cars_inputs_test)
lr_accuracy = accuracy_score(cars_output_test, lr_pred)
results.append({'Model': 'Logistic Regression', 'Time Taken (s)': lr_training_time, 'Memory Used (MB)': lr_memory_used, 'Accuracy': lr_accuracy})

# SVM
svm_start_time = time.time()
svm_classifier = SVC(kernel='rbf', random_state=45011)
svm_classifier.fit(cars_inputs_train, cars_output_train)
svm_training_time = time.time() - svm_start_time
svm_memory_used = memory_usage()
svm_pred = svm_classifier.predict(cars_inputs_test)
svm_accuracy = accuracy_score(cars_output_test, svm_pred)
results.append({'Model': 'SVM', 'Time Taken (s)': svm_training_time, 'Memory Used (MB)': svm_memory_used, 'Accuracy': svm_accuracy})

# Create DataFrame
results_df = pd.DataFrame(results)

# Display the results
print(results_df)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#                  Model  Time Taken (s)  Memory Used (MB)  Accuracy
# 0        Decision Tree        0.115021        546.699219  0.999881
# 1            KNN (k=5)        0.102144        546.699219  0.484645
# 2            KNN (k=7)        0.116892        546.699219  0.442554
# 3            KNN (k=9)        0.163790        546.699219  0.416765
# 4           KNN (k=11)        0.100298        546.699219  0.417773
# 5           KNN (k=13)        0.101557        546.699219  0.437693
# 6           KNN (k=15)        0.099797        546.699219  0.487788
# 7  Logistic Regression        1.420141        546.699219  0.860446
# 8                  SVM      309.868165        552.113281  0.366730
